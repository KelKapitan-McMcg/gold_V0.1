# %%
#### CREATE YEAR CANDLES WITH BOXPLOT ####
#!pip install seaborn
#!pip install numpy
#!pip install matplotlib
#!pip install pandas
#!pip install --upgrade mplfinance

import numpy as np
import pandas as pd # for DataFrame use
import matplotlib.pyplot as plt # For plotting graphics
import seaborn as sns # For plotting graphics
import mplfinance as mpf # For the plotting of Candlestick data

# %%
# Import Data

gold = pd.read_csv("gold_price_data.csv")

print(gold.head())
print(gold.tail())
# Out:
#          Date  Value
# 0  1970-01-01   35.2
# 1  1970-04-01   35.1
# 2  1970-07-01   35.4
# 3  1970-10-01   36.2
# 4  1971-01-01   37.4
#              Date    Value
# 10782  2020-03-09  1672.50
# 10783  2020-03-10  1655.70
# 10784  2020-03-11  1653.75
# 10785  2020-03-12  1570.70
# 10786  2020-03-13  1562.80

# %%
# Convert the date column to a datetime object
gold['Date'] = pd.to_datetime(gold.loc[:,'Date']) 

# Adding a month and yearcolumn
gold['month'] = gold['Date'].dt.month
gold['year'] = gold['Date'].dt.year

print(gold.head())
print(gold.tail())
# Out:
#         Date  Value  month  year
# 0 1970-01-01   35.2      1  1970
# 1 1970-04-01   35.1      4  1970
# 2 1970-07-01   35.4      7  1970
# 3 1970-10-01   36.2     10  1970
# 4 1971-01-01   37.4      1  1971
#             Date    Value  month  year
# 10782 2020-03-09  1672.50      3  2020
# 10783 2020-03-10  1655.70      3  2020
# 10784 2020-03-11  1653.75      3  2020
# 10785 2020-03-12  1570.70      3  2020
# 10786 2020-03-13  1562.80      3  2020

# %%
# Put the data into relevant year
year_1970 = gold[gold['year'] == 1970]
year_1971 = gold[gold['year'] == 1971]
year_1972 = gold[gold['year'] == 1972]
year_1973 = gold[gold['year'] == 1973]
year_1974 = gold[gold['year'] == 1974]
year_1975 = gold[gold['year'] == 1975]
year_1976 = gold[gold['year'] == 1976]
year_1977 = gold[gold['year'] == 1977]
year_1978 = gold[gold['year'] == 1978]
year_1979 = gold[gold['year'] == 1979]
year_1980 = gold[gold['year'] == 1980]
year_1981 = gold[gold['year'] == 1981]
year_1982 = gold[gold['year'] == 1982]
year_1983 = gold[gold['year'] == 1983]
year_1984 = gold[gold['year'] == 1984]
year_1985 = gold[gold['year'] == 1985]
year_1986 = gold[gold['year'] == 1986]
year_1987 = gold[gold['year'] == 1987]
year_1988 = gold[gold['year'] == 1988]
year_1989 = gold[gold['year'] == 1989]
year_1990 = gold[gold['year'] == 1990]
year_1991 = gold[gold['year'] == 1991]
year_1992 = gold[gold['year'] == 1992]
year_1993 = gold[gold['year'] == 1993]
year_1994 = gold[gold['year'] == 1994]
year_1995 = gold[gold['year'] == 1995]
year_1996 = gold[gold['year'] == 1996]
year_1997 = gold[gold['year'] == 1997]
year_1998 = gold[gold['year'] == 1998]
year_1999 = gold[gold['year'] == 1999]

# Create empty lists to hold OHLC & Date
c_1970 = []
c_1971 = []
c_1972 = []
c_1973 = []
c_1974 = []
c_1975 = []
c_1976 = []
c_1977 = []
c_1978 = []
c_1979 = []
c_1980 = []
c_1981 = []
c_1982 = []
c_1983 = []
c_1984 = []
c_1985 = []
c_1986 = []
c_1987 = []
c_1988 = []
c_1989 = []
c_1990 = []
c_1991 = []
c_1992 = []
c_1993 = []
c_1994 = []
c_1995 = []
c_1996 = []
c_1997 = []
c_1998 = []
c_1999 = []

# Fill the year data into the relevant year
for index, row in gold.iterrows(): 
    
    if row['year'] == 1970:
        c_1970.append((row['Date'],row['Value']))
    if row['year'] == 1971:
        c_1971.append((row['Date'],row['Value']))
    if row['year'] == 1972:
        c_1972.append((row['Date'],row['Value']))
    if row['year'] == 1973:
        c_1973.append((row['Date'],row['Value']))
    if row['year'] == 1974:
        c_1974.append((row['Date'],row['Value']))
    if row['year'] == 1975:
        c_1975.append((row['Date'],row['Value']))
    if row['year'] == 1976:
        c_1976.append((row['Date'],row['Value']))
    if row['year'] == 1977:
        c_1977.append((row['Date'],row['Value']))
    if row['year'] == 1978:
        c_1978.append((row['Date'],row['Value']))
    if row['year'] == 1979:
        c_1979.append((row['Date'],row['Value']))
    if row['year'] == 1980:
        c_1980.append((row['Date'],row['Value']))
    if row['year'] == 1981:
        c_1981.append((row['Date'],row['Value']))
    if row['year'] == 1982:
        c_1982.append((row['Date'],row['Value']))
    if row['year'] == 1983:
        c_1983.append((row['Date'],row['Value']))
    if row['year'] == 1984:
        c_1984.append((row['Date'],row['Value']))
    if row['year'] == 1985:
        c_1985.append((row['Date'],row['Value']))
    if row['year'] == 1986:
        c_1986.append((row['Date'],row['Value']))
    if row['year'] == 1987:
        c_1987.append((row['Date'],row['Value']))
    if row['year'] == 1988:
        c_1988.append((row['Date'],row['Value']))
    if row['year'] == 1989:
        c_1989.append((row['Date'],row['Value']))
    if row['year'] == 1990:
        c_1990.append((row['Date'],row['Value']))
    if row['year'] == 1991:
        c_1991.append((row['Date'],row['Value']))
    if row['year'] == 1992:
        c_1992.append((row['Date'],row['Value']))
    if row['year'] == 1993:
        c_1993.append((row['Date'],row['Value']))
    if row['year'] == 1994:
        c_1994.append((row['Date'],row['Value']))
    if row['year'] == 1995:
        c_1995.append((row['Date'],row['Value']))
    if row['year'] == 1996:
        c_1996.append((row['Date'],row['Value']))
    if row['year'] == 1997:
        c_1997.append((row['Date'],row['Value']))
    if row['year'] == 1998:
        c_1998.append((row['Date'],row['Value']))
    if row['year'] == 1999:
        c_1999.append((row['Date'],row['Value']))
          
# create an outer list of lists to append all data in sequential order
candles = []

candles.append(c_1970)
candles.append(c_1971)
candles.append(c_1972)
candles.append(c_1973)
candles.append(c_1974)
candles.append(c_1975)
candles.append(c_1976)
candles.append(c_1977)
candles.append(c_1978)
candles.append(c_1979)
candles.append(c_1980)
candles.append(c_1981)
candles.append(c_1982)
candles.append(c_1983)
candles.append(c_1984)
candles.append(c_1985)
candles.append(c_1986)
candles.append(c_1987)
candles.append(c_1988)
candles.append(c_1989)
candles.append(c_1990)
candles.append(c_1991)
candles.append(c_1992)
candles.append(c_1993)
candles.append(c_1994)
candles.append(c_1995)
candles.append(c_1996)
candles.append(c_1997)
candles.append(c_1998)
candles.append(c_1999)

# candles is the entire dataset organised, Quality check To be done here
#print(candles)

# Convert each list into Data Frames
labels = ['date', 'price']
df_1970 = pd.DataFrame.from_records(candles[0], columns=labels)
df_1971 = pd.DataFrame.from_records(candles[1], columns=labels)
df_1972 = pd.DataFrame.from_records(candles[2], columns=labels)
df_1973 = pd.DataFrame.from_records(candles[3], columns=labels)
df_1974 = pd.DataFrame.from_records(candles[4], columns=labels)
df_1975 = pd.DataFrame.from_records(candles[5], columns=labels)
df_1976 = pd.DataFrame.from_records(candles[6], columns=labels)
df_1977 = pd.DataFrame.from_records(candles[7], columns=labels)
df_1978 = pd.DataFrame.from_records(candles[8], columns=labels)
df_1979 = pd.DataFrame.from_records(candles[9], columns=labels)
df_1980 = pd.DataFrame.from_records(candles[10], columns=labels)
df_1981 = pd.DataFrame.from_records(candles[11], columns=labels)
df_1982 = pd.DataFrame.from_records(candles[12], columns=labels)
df_1983 = pd.DataFrame.from_records(candles[13], columns=labels)
df_1984 = pd.DataFrame.from_records(candles[14], columns=labels)
df_1985 = pd.DataFrame.from_records(candles[15], columns=labels)
df_1986 = pd.DataFrame.from_records(candles[16], columns=labels)
df_1987 = pd.DataFrame.from_records(candles[17], columns=labels)
df_1988 = pd.DataFrame.from_records(candles[18], columns=labels)
df_1989 = pd.DataFrame.from_records(candles[19], columns=labels)
df_1990 = pd.DataFrame.from_records(candles[20], columns=labels)
df_1991 = pd.DataFrame.from_records(candles[21], columns=labels)
df_1992 = pd.DataFrame.from_records(candles[22], columns=labels)
df_1993 = pd.DataFrame.from_records(candles[23], columns=labels)
df_1994 = pd.DataFrame.from_records(candles[24], columns=labels)
df_1995 = pd.DataFrame.from_records(candles[25], columns=labels)
df_1996 = pd.DataFrame.from_records(candles[26], columns=labels)
df_1997 = pd.DataFrame.from_records(candles[27], columns=labels)
df_1998 = pd.DataFrame.from_records(candles[28], columns=labels)
df_1999 = pd.DataFrame.from_records(candles[29], columns=labels)




# get the high and low open and close values and add to new DF called df_yearly


new_label = ['year', 'Open', 'High', 'Low', 'Close']

ohlc_1990 = []
ohlc_1990.append(1990)
ohlc_1990.append(df_1990['price'][0])
ohlc_1990.append(df_1990['price'].max())
ohlc_1990.append(df_1990['price'].min())
ohlc_1990.append(df_1990['price'][260])

ohlc_1991 = []
ohlc_1991.append(1991)
ohlc_1991.append(df_1991['price'][0])
ohlc_1991.append(df_1991['price'].max())
ohlc_1991.append(df_1991['price'].min())
ohlc_1991.append(df_1991['price'][260])

ohlc_1992 = []
ohlc_1992.append(1992)
ohlc_1992.append(df_1992['price'][0])
ohlc_1992.append(df_1992['price'].max())
ohlc_1992.append(df_1992['price'].min())
ohlc_1992.append(df_1992['price'][260])

ohlc_1993 = []
ohlc_1993.append(1993)
ohlc_1993.append(df_1993['price'][0])
ohlc_1993.append(df_1993['price'].max())
ohlc_1993.append(df_1993['price'].min())
ohlc_1993.append(df_1993['price'][260])

ohlc_1994 = []
ohlc_1994.append(1994)
ohlc_1994.append(df_1994['price'][0])
ohlc_1994.append(df_1994['price'].max())
ohlc_1994.append(df_1994['price'].min())
ohlc_1994.append(df_1994['price'][250])

ohlc_1995 = []
ohlc_1995.append(1995)
ohlc_1995.append(df_1995['price'][0])
ohlc_1995.append(df_1995['price'].max())
ohlc_1995.append(df_1995['price'].min())
ohlc_1995.append(df_1995['price'][250])

ohlc_1996 = []
ohlc_1996.append(1996)
ohlc_1996.append(df_1996['price'][0])
ohlc_1996.append(df_1996['price'].max())
ohlc_1996.append(df_1996['price'].min())
ohlc_1996.append(df_1996['price'][260])

ohlc_1997 = []
ohlc_1997.append(1997)
ohlc_1997.append(df_1997['price'][0])
ohlc_1997.append(df_1997['price'].max())
ohlc_1997.append(df_1997['price'].min())
ohlc_1997.append(df_1997['price'][260])

ohlc_1998 = []
ohlc_1998.append(1998)
ohlc_1998.append(df_1998['price'][0])
ohlc_1998.append(df_1998['price'].max())
ohlc_1998.append(df_1998['price'].min())
ohlc_1998.append(df_1998['price'][260])

ohlc_1999 = []
ohlc_1999.append(1999)
ohlc_1999.append(df_1999['price'][0])
ohlc_1999.append(df_1999['price'].max())
ohlc_1999.append(df_1999['price'].min())
ohlc_1999.append(df_1999['price'][260])




year_ohlc = []

year_ohlc.append(ohlc_1990)
year_ohlc.append(ohlc_1991)
year_ohlc.append(ohlc_1992)
year_ohlc.append(ohlc_1993)
year_ohlc.append(ohlc_1994)
year_ohlc.append(ohlc_1995)
year_ohlc.append(ohlc_1996)
year_ohlc.append(ohlc_1997)
year_ohlc.append(ohlc_1998)
year_ohlc.append(ohlc_1999)



# Convert list to DataFrame
df_yearly = pd.DataFrame.from_records(year_ohlc, columns=new_label)
print(df_yearly.head())
# Out:
#    year    Open    High     Low   Close
# 0  1990  398.60  423.75  345.85  386.20
# 1  1991  386.20  403.00  344.25  353.15
# 2  1992  353.15  359.60  330.35  332.90
# 3  1993  332.90  405.60  326.10  391.75
# 4  1994  391.75  396.25  369.65  379.20

# %%
# Convert new date column from year column as a DateTimeIndex
df_yearly['date'] = df_yearly['year']
df_yearly['date'] = pd.to_datetime(df_yearly['date'].astype('str'))
df_yearly = df_yearly.set_index('date')

# Plot the yearly candles
mpf.plot(df_yearly, type='candle')
